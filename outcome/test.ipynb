# %%
import pandas as pd

# %%
df = pd.read_csv("combined_daily_returns_20250425_141840.csv")

# %%
df.drop(columns=["P-Y"], inplace=True)

# %%
df
# Out:
#             date      J-JM      OI-Y      L-MA
# 0     2017-02-21  0.000000  0.000000  0.000000
# 1     2017-02-22  0.000000  0.000000  0.000000
# 2     2017-02-23  0.000000  0.000000  0.000000
# 3     2017-02-24  0.000000  0.000000  0.000000
# 4     2017-02-27  0.000000  0.000000  0.000000
# ...          ...       ...       ...       ...
# 1908  2024-12-25  0.000340  0.001292  0.000373
# 1909  2024-12-26 -0.000175  0.000707 -0.001806
# 1910  2024-12-27  0.001174 -0.000238 -0.000114
# 1911  2024-12-30  0.000206  0.001219  0.003460
# 1912  2024-12-31 -0.000465 -0.004244  0.000150
#
# [1913 rows x 4 columns]

# %%
df['sum'] = df['J-JM'] + df['OI-Y'] + df['L-MA']
# Out:
# <Axes: >

# %%
df['cumulative_return'] = (1 + df['sum']).cumprod() 

df['cumulative_return'].plot()
# Out:
# <Axes: >
